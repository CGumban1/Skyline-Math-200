# %% [markdown]
# <a href="https://colab.research.google.com/github/CGumban1/Skyline-Math-200/blob/main/Python_Notebook_Setup_by_CGumban.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IS THERE AN ASSOCIATION BETWEEN SCHOOL/ WORK DAYS MISSED AND BEDTIME?**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# Codebook 1 (School/ work days missed)

# %% [markdown]
# ![Screen Shot 2023-04-28 at 10.48.47 AM.png](data:image/png;base64,...)

# %% [markdown]
# Frequency Table   ![Screen Shot 2023-04-28 at 10.49.54 AM.png](data:image/png;base64,...)

# %%
#Frequency Table Code:
rp.summary_cat(df['Days_missed'])

# %% [markdown]
# PIE CHART:

# %% [markdown]
# ![Screen Shot 2023-04-30 at 9.21.07 PM.png](data:image/png;base64,...)

# %%
#Pie Chart Code:
df['EXP'].value_counts().plot(kind ='pie', autopct='%1.1f%%')

# %% [markdown]
# BAR GRAPH
# ![Screen Shot 2023-04-28 at 10.58.58 AM.png](data:image/png;base64,...)

# %%
#Bar Graph Code: plt.xlabel("Amount of Friends")
plt.ylabel("Percent")
plt.title("How many close friends do you have?")
df['EXP'].value_counts(normalize = True).plot(kind ='bar', color = 'red', width = 0.5, alpha = 0.5)

# %% [markdown]
# *Codebook* 2: BEDTIME

# %%
#Manage data for variable 2

# %% [markdown]
# ![Screen Shot 2023-04-30 at 2.58.55 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-04-30 at 2.59.01 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-04-30 at 2.59.22 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2023-04-30 at 2.59.31 PM.png](data:image/png;base64,...)

# %% [markdown]
# Frequency Table: ![Screen Shot 2023-04-30 at 4.56.18 PM.png](data:image/png;base64,...)

# %%
#Frequency Table Code:
df['Bedtime_Military_Times'].describe()

# %% [markdown]
# Basic Statistical Measures: ![Screen Shot 2023-04-30 at 5.15.26 PM.png](data:image/png;base64,...)

# %%
#Basic Statistical Measures Code:
df['Bedtime_Military_Times'].max()
df['Bedtime_Military_Times'].mean()
df['Bedtime_Military_Times'].median()

# %% [markdown]
# Histogram: ![Screen Shot 2023-04-30 at 5.16.14 PM.png](data:image/png;base64,...)

# %%
#Histogram Code:
sns.histplot(x = 'Bedtime_Military_Times', data =df, stat='percent', bins = 15)

# %% [markdown]
# Histogram with Normal Curve: ![Screen Shot 2023-04-30 at 5.19.33 PM.png](data:image/png;base64,...)

# %%
#Histogram Code:
sns.histplot(x='Bedtime_Military_Times', data = df, bins = 15, kde=True)

# %% [markdown]
# Boxplot:  ![Screen Shot 2023-04-30 at 5.16.22 PM.png](data:image/png;base64,...)

# %%
#Boxplot Code:
sns.boxplot( x = 'Bedtime_Military_Times', data = df)

# %% [markdown]
# # **IS THERE AN ASSOCIATION BETWEEN THE AMOUNT OF THE AMOUNT OF CURRENT SEXUAL/ ROMANTIC PARTNERS AND THE AMOUNT OF CLOSE FRIENDS?**

# %% [markdown]
# CODEBOOK FOR VARIABLE 1: AMOUNT OF CLOSE FRIENDS

# %% [markdown]
# ![Screen Shot 2023-04-30 at 5.21.09 PM.png](data:image/png;base64,...)

# %% [markdown]
# FREQUENCY TABLE:

# %% [markdown]
# ![Screen Shot 2023-04-30 at 5.31.45 PM.png](data:image/png;base64,...)

# %%
#Frequency Table Code:
rp.summary_cat(df['Friend_amount'])

# %% [markdown]
# BAR GRAPH:

# %% [markdown]
# ![Screen Shot 2023-04-30 at 8.29.03 PM.png](data:image/png;base64,...)

# %%
#Bar Graph Code:
plt.xlabel("Amount of Friends")
plt.ylabel("Percent")
plt.title("How many close friends do you have?")
df['EXP'].value_counts(normalize = True).plot(kind ='bar', color = 'red', width = 0.5, alpha = 0.5)

# %% [markdown]
# PIE CHART:

# %% [markdown]
# ![Screen Shot 2023-04-30 at 8.29.33 PM.png](data:image/png;base64,...)

# %%
#Pie Chart Code: 
plt.title("How many close friends do you have?")
df['EXP'].value_counts().plot(kind ='pie', autopct='%1.1f%%', colors=['lightgrey', 'lightblue', 'gray', 'mediumslateblue', 'aqua'])

# %% [markdown]
# EXPLODE:

# %% [markdown]
# ![Screen Shot 2023-04-30 at 8.30.17 PM.png](data:image/png;base64,...)

# %%
#Explode Pie Chart Code:
explode = (0.1, 0.1, 0.4, 0.2, 0.3)
df['EXP'].value_counts().plot(kind ='pie', autopct='%1.1f%%',  explode=explode, shadow=True, startangle=90)
plt.legend(loc ="lower right")

# %% [markdown]
# CODEBOOK FOR VARIABLE 1: AMOUNT OF CURRENT SEXUAL/ ROMANTIC PARTNERS

# %% [markdown]
# ![Screen Shot 2023-04-30 at 8.31.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# BASIC STATISTICAL MEASURES:

# %% [markdown]
# ![Screen Shot 2023-04-30 at 8.33.43 PM.png](data:image/png;base64,...)

# %%
#Basic Statistical Measures Code:
rp.summarize(df['Relationship_amount'])
rp.summary_cont(df['Relationship_amount'])
df['Relationship_amount'].describe()

# %% [markdown]
# HISTOGRAM WITH NORMAL LINE:

# %% [markdown]
# ![Screen Shot 2023-04-30 at 8.34.29 PM.png](data:image/png;base64,...)

# %%
#Histogram Code:
sns.histplot(x='Relationship_amount', data = df, bins = 15, kde=True)

# %% [markdown]
# BOXPLOT:

# %% [markdown]
# ![Screen Shot 2023-04-30 at 8.34.34 PM.png](data:image/png;base64,...)

# %%
#Boxplot Code:
sns.boxplot( x = 'Relationship_amount', data = df)
